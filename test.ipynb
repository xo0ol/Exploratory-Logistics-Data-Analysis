# %%
print('hello')
# Out:
# hello

# %% [markdown]
# 통계 분석
#
# 1. 품목별(Item ID)
# * 평균 이동 횟수
# * 최대/최소 이동량
#
# 2. 창고별(Warehouse ID)
# * 평균 이동 횟수
# * 최대/최소 이동량

# %% [markdown]
# 시간별 트렌드 분석
# * 일/주/월별 전체 이동량 및 이동 횟수 변화 시각화
#  - 주기성이나 갑작스러운 변동 감지
#
# * 일/주/월별 Top5 이동 품목
#
# * 일/주/월별 Top5 이동 창고
#
# * 입/출고 시간대 분석
#  - 입고 및 출고가 특정 시간대에 집중하는지 확인
#  - Movement Date

# %% [markdown]
# 재고 회전율 분석
# * 특정 기간(예: 2025년 5월)동안 각 품목이 입고/출고된 횟수
# * 회전률이 낮은 품목

# %% [markdown]
# 추가 인사이트
# * Movement Type에 따라 처리 시간을 확인할 수 있는 작업 소요 필드 필요.
# * 작업 로그별 오류 횟수 필드가 있다면 오류 분석에 유용할 것.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_location = './datasets/warehouse-inventory-movement-log.csv'
movement_log_df = pd.read_csv(data_location)
movement_log_df.head()
# Out:
#   movement_id            timestamp   item_id             item_name  \
# 0    MV000001  2024-03-04T08:19:00  ITM-1012   Plastic Storage Bin
# 1    MV000002  2024-03-04T09:42:15  ITM-1045   Aluminum Sheet Roll
# 2    MV000003  2024-03-04T10:11:00  ITM-1008  Corrugated Box Large
# 3    MV000004  2024-03-04T10:37:36  ITM-1030    Packing Tape Clear
# 4    MV000005  2024-03-04T11:02:20  ITM-1024           Blue Pallet
#
#            sku  batch_number  quantity      uom movement_type  \
# 0  SKU-PLB-002    BN-202403A        32   pieces       inbound
# 1  SKU-ALM-019    ALM-2402-B        -5    rolls      outbound
# 2  SKU-CBX-003           NaN       100   pieces       inbound
# 3  SKU-PTC-015  PTC-20240301       -24    boxes      outbound
# 4  SKU-PAL-001           NaN        12  pallets       inbound
#
#   source_location_id source_location_name destination_location_id  \
# 0                NaN                  NaN                 BIN-17C
# 1            RACK-2B              Rack 2B                     NaN
# 2                NaN                  NaN                  BIN-9A
# 3             BIN-3E      Aisle 1, Bin 3E                     NaN
# 4                NaN                  NaN                 DOCK-01
#
#   destination_location_name operator_id  operator_name reference_document  \
# 0          Aisle 5, Bin 17C      OP-003     Dana Patel     PO-20240302-11
# 1                       NaN      OP-005     Luke Chang     SO-20240304-04
# 2           Aisle 2, Bin 9A      OP-001   Samantha Lee     PO-20240302-06
# 3                       NaN      OP-007  Jayden Brooks     SO-20240304-07
# 4         Receiving Dock 01      OP-009  Erika Schmidt     PO-20240301-27
#
#   movement_reason                        comments
# 0   replenishment  Morning delivery from supplier
# 1         picking       Dispatched for order 1124
# 2   replenishment                             NaN
# 3         picking            For express shipment
# 4   replenishment                             NaN

# %% [markdown]
# # 변수 정리

# %% [markdown]
# ## 1. 분석에 필요한 데이터 남기기

# %%
# df = movement_log_df.iloc[:, :-4].copy()

df = movement_log_df.copy()
drop_vars = ['item_name', 'uom', 'destination_location_name',
             'operator_name', 'reference_document', 'comments']
df.drop(columns=drop_vars, axis=1, inplace=True)
df.head()
# Out:
#   movement_id            timestamp   item_id          sku  batch_number  \
# 0    MV000001  2024-03-04T08:19:00  ITM-1012  SKU-PLB-002    BN-202403A
# 1    MV000002  2024-03-04T09:42:15  ITM-1045  SKU-ALM-019    ALM-2402-B
# 2    MV000003  2024-03-04T10:11:00  ITM-1008  SKU-CBX-003           NaN
# 3    MV000004  2024-03-04T10:37:36  ITM-1030  SKU-PTC-015  PTC-20240301
# 4    MV000005  2024-03-04T11:02:20  ITM-1024  SKU-PAL-001           NaN
#
#    quantity movement_type source_location_id source_location_name  \
# 0        32       inbound                NaN                  NaN
# 1        -5      outbound            RACK-2B              Rack 2B
# 2       100       inbound                NaN                  NaN
# 3       -24      outbound             BIN-3E      Aisle 1, Bin 3E
# 4        12       inbound                NaN                  NaN
#
#   destination_location_id operator_id movement_reason
# 0                 BIN-17C      OP-003   replenishment
# 1                     NaN      OP-005         picking
# 2                  BIN-9A      OP-001   replenishment
# 3                     NaN      OP-007         picking
# 4                 DOCK-01      OP-009   replenishment

# %% [markdown]
# ## 날짜에서 date, time 추출 및 시간 데이터 변환

# %%
df[['date', 'time']] = df['timestamp'].str.split('T', expand=True)
for i in ['timestamp', 'date']:
    df[i] = pd.to_datetime(df[i], errors='coerce')

df['time'] = pd.to_datetime(df['time'], errors='coerce', format='%H:%M:%S').dt.time
# dt.time으로 가짜 날짜 1900-01-01 제거하고 시간 정보만 추출
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df[['date', 'time']] = df['timestamp'].str.split('T', expand=True)
#       2 for i in ['timestamp', 'date']:
#       3     df[i] = pd.to_datetime(df[i], errors='coerce')
#
# File c:\Users\xo0ol\Github\Analysis Logistics Warehouse Data\.venv\Lib\site-packages\pandas\core\generic.py:6321, in NDFrame.__getattr__(self, name)
#    6314 if (
#    6315     name not in self._internal_names_set
#    6316     and name not in self._metadata
#    6317     and name not in self._accessors
#    6318     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319 ):
#    6320     return self[name]
# -> 6321 return object.__getattribute__(self, name)
#
# File c:\Users\xo0ol\Github\Analysis Logistics Warehouse Data\.venv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\xo0ol\Github\Analysis Logistics Warehouse Data\.venv\Lib\site-packages\pandas\core\strings\accessor.py:194, in StringMethods.__init__(self, data)
#     191 def __init__(self, data) -> None:
#     192     from pandas.core.arrays.string_ import StringDtype
# --> 194     self._inferred_dtype = self._validate(data)
#     195     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     196     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\xo0ol\Github\Analysis Logistics Warehouse Data\.venv\Lib\site-packages\pandas\core\strings\accessor.py:248, in StringMethods._validate(data)
#     245 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     247 if inferred_dtype not in allowed_types:
# --> 248     raise AttributeError("Can only use .str accessor with string values!")
#     249 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   movement_id              200 non-null    object
#  1   timestamp                200 non-null    datetime64[ns]
#  2   item_id                  200 non-null    object
#  3   sku                      200 non-null    object
#  4   batch_number             107 non-null    object
#  5   quantity                 200 non-null    int64
#  6   movement_type            200 non-null    object
#  7   source_location_id       112 non-null    object
#  8   source_location_name     112 non-null    object
#  9   destination_location_id  128 non-null    object
#  10  operator_id              200 non-null    object
#  11  movement_reason          200 non-null    object
#  12  date                     200 non-null    datetime64[ns]
#  13  time                     200 non-null    object
# dtypes: datetime64[ns](2), int64(1), object(11)
# memory usage: 22.0+ KB

# %%
df['movement_reason'].unique()
# Out:
# array(['replenishment', 'picking', 'cycle count', 'customer return',
#        'shipping', 'damage', 'reallocation'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   movement_id              200 non-null    object
#  1   timestamp                200 non-null    datetime64[ns]
#  2   item_id                  200 non-null    object
#  3   sku                      200 non-null    object
#  4   batch_number             107 non-null    object
#  5   quantity                 200 non-null    int64
#  6   movement_type            200 non-null    object
#  7   source_location_id       112 non-null    object
#  8   source_location_name     112 non-null    object
#  9   destination_location_id  128 non-null    object
#  10  operator_id              200 non-null    object
#  11  movement_reason          200 non-null    object
#  12  date                     200 non-null    object
#  13  time                     200 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(12)
# memory usage: 22.0+ KB

# %%
df[df['movement_type'] == 'inbound']['quantity'].describe()
# Out:
# count     67.000000
# mean      47.522388
# std       58.199593
# min        1.000000
# 25%       12.000000
# 50%       30.000000
# 75%       60.000000
# max      300.000000
# Name: quantity, dtype: float64

# %%
df[df['movement_type'] == 'outbound']['quantity'].describe()
# Out:
# count     60.00000
# mean     -35.45000
# std       46.82004
# min     -200.00000
# 25%      -40.00000
# 50%      -15.00000
# 75%       -8.00000
# max       -1.00000
# Name: quantity, dtype: float64

# %%
df[['date', 'time']] = df['timestamp'].astype(str).str.split('T', expand=True)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
